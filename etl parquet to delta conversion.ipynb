# %%
input_path = "s3://retail-dataset-01/stage/data/2026/01/03/07/"
output_path = "s3://retail-dataset-01/stage/delta_table/"

df = spark.read.parquet(input_path)
df.write.format("delta").mode("overwrite").save(output_path)
df.display()
